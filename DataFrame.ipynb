# %%
import pandas as kudi

# %%
df = kudi.read_csv("telco_churn.csv") #read_csv() ------> This is known as a method

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# # Read The Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3323 non-null   float64
#  7   Total day calls         3323 non-null   float64
#  8   Total day charge        3315 non-null   float64
#  9   Total eve minutes       3324 non-null   float64
#  10  Total eve calls         3325 non-null   float64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3332 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df[['Account length', 'Total intl charge']]
# Out:
#       Account length  Total intl charge
# 0                128               2.70
# 1                107               3.70
# 2                137               3.29
# 3                 84               1.78
# 4                 75               2.73
# ...              ...                ...
# 3328             192               2.67
# 3329              68               2.59
# 3330              28               3.81
# 3331             184               1.35
# 3332              74               3.70
#
# [3333 rows x 2 columns]

# %%
df.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
#filtering rows; we use two things: iloc() and loc()

df.iloc[2:4]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 2             41.38              121.2            110.0             10.30
# 3             50.90               61.9             88.0              5.26
#
#    Total night minutes  Total night calls  Total night charge  \
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 2                12.2                 5               3.29
# ...

# %%
df.loc[2:6]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
# 5                      0              223.4             98.0
# 6                     24              218.2             88.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 2             41.38              121.2            110.0             10.30
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3323 non-null   float64
#  7   Total day calls         3323 non-null   float64
#  8   Total day charge        3315 non-null   float64
#  9   Total eve minutes       3324 non-null   float64
#  10  Total eve calls         3325 non-null   float64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3332 non-null   float64
# ...

# %%
df.loc[df["Account length"]]
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 128    TX              92        408                 No              No
# 107    NM              93        510                 No             Yes
# 137    FL              91        510                 No              No
# 84     TX             106        510                 No              No
# 75     MN              50        415                 No              No
# ..    ...             ...        ...                ...             ...
# 192    KY              80        408                 No              No
# 68     UT             126        408                 No              No
# 28     MO              20        415                 No              No
# 184    VA             170        510                Yes              No
# 74     HI              85        415                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.loc[0:4]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.loc[2]
# Out:
# State                        NJ
# Account length              137
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         243.4
# Total day calls           114.0
# Total day charge          41.38
# Total eve minutes         121.2
# Total eve calls           110.0
# Total eve charge           10.3
# Total night minutes       162.6
# Total night calls         104.0
# Total night charge         7.32
# Total intl minutes         12.2
# Total intl calls              5
# Total intl charge          3.29
# Customer service calls      0.0
# Churn                     False
# Name: 2, dtype: object

# %%
df.loc[df["Account length"]]
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 128    TX              92        408                 No              No
# 107    NM              93        510                 No             Yes
# 137    FL              91        510                 No              No
# 84     TX             106        510                 No              No
# 75     MN              50        415                 No              No
# ..    ...             ...        ...                ...             ...
# 192    KY              80        408                 No              No
# 68     UT             126        408                 No              No
# 28     MO              20        415                 No              No
# 184    VA             170        510                Yes              No
# 74     HI              85        415                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#Conditional Filtering;

df[                 df['International plan'] == 'Yes'                       ]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# 7       MO             147        415                Yes              No
# 9       WV             141        415                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3304    IL              71        510                Yes              No
# 3309    VT             100        408                Yes              No
# 3317    SD             163        415                Yes              No
# 3320    GA             122        510                Yes              No
# 3331    CT             184        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# Having for more that two conditions
df[                 (df['International plan'] == 'Yes') & (df['Voice mail plan'] == 'Yes')                         ]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 9       WV             141        415                Yes             Yes
# 38      AK             136        415                Yes             Yes
# 41      MD             135        408                Yes             Yes
# 115     ME              36        510                Yes             Yes
# 180     WV              94        510                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 2847    ID             119        415                Yes             Yes
# 3209    OH              68        415                Yes             Yes
# 3222    UT              61        415                Yes             Yes
# 3246    NC              77        408                Yes             Yes
# 3291    MI             119        510                Yes             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[                 (df['International plan'] == 'Yes') | (df['Voice mail plan'] == 'Yes')                         ] # the or symbl is representaed by |
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# ...    ...             ...        ...                ...             ...
# 3317    SD             163        415                Yes              No
# 3320    GA             122        510                Yes              No
# 3328    AZ             192        415                 No             Yes
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# # Update Data

# %%
df.isnull().sum() #Use to check for missing values in the DataFrame
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
cleaned_df = df.dropna()

cleaned_df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
cleaned_df = cleaned_df.drop('Voice mail plan', axis=1)   #To Remove a column

# %%
cleaned_df
# Out:
#      State  Account length  Area code International plan  \
# 0       KS             128        415                 No
# 1       OH             107        415                 No
# 2       NJ             137        415                 No
# 3       OH              84        408                Yes
# 4       OK              75        415                Yes
# ...    ...             ...        ...                ...
# 3328    AZ             192        415                 No
# 3329    WV              68        415                 No
# 3330    RI              28        510                 No
# 3331    CT             184        510                Yes
# 3332    TN              74        415                 No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# 2                         0              243.4            114.0
# ...

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3307 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3307 non-null   object
#  1   Account length          3307 non-null   int64
#  2   Area code               3307 non-null   int64
#  3   International plan      3307 non-null   object
#  4   Number vmail messages   3307 non-null   int64
#  5   Total day minutes       3307 non-null   float64
#  6   Total day calls         3307 non-null   float64
#  7   Total day charge        3307 non-null   float64
#  8   Total eve minutes       3307 non-null   float64
#  9   Total eve calls         3307 non-null   float64
#  10  Total eve charge        3307 non-null   float64
#  11  Total night minutes     3307 non-null   float64
#  12  Total night calls       3307 non-null   float64
#  13  Total night charge      3307 non-null   float64
# ...

# %%
#Adding a New Infomation into our data set
cleaned_df['Nigerian Charges'] = 100

# %%
cleaned_df
# Out:
#      State  Account length  Area code International plan  \
# 0       KS             128        415                 No
# 1       OH             107        415                 No
# 2       NJ             137        415                 No
# 3       OH              84        408                Yes
# 4       OK              75        415                Yes
# ...    ...             ...        ...                ...
# 3328    AZ             192        415                 No
# 3329    WV              68        415                 No
# 3330    RI              28        510                 No
# 3331    CT             184        510                Yes
# 3332    TN              74        415                 No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# 2                         0              243.4            114.0
# ...

# %%
#Aggregated Additions

cleaned_df['grand_total'] = cleaned_df['Total day calls'] + cleaned_df['Total eve calls']

# %%
cleaned_df
# Out:
#      State  Account length  Area code International plan  \
# 0       KS             128        415                 No
# 1       OH             107        415                 No
# 2       NJ             137        415                 No
# 3       OH              84        408                Yes
# 4       OK              75        415                Yes
# ...    ...             ...        ...                ...
# 3328    AZ             192        415                 No
# 3329    WV              68        415                 No
# 3330    RI              28        510                 No
# 3331    CT             184        510                Yes
# 3332    TN              74        415                 No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# 2                         0              243.4            114.0
# ...

# %%
#Adding a New Column Base on a Condition

cleaned_df ['Agg_Voice_Note'] = cleaned_df['International plan'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
cleaned_df
# Out:
#      State  Account length  Area code International plan  \
# 0       KS             128        415                 No
# 1       OH             107        415                 No
# 2       NJ             137        415                 No
# 3       OH              84        408                Yes
# 4       OK              75        415                Yes
# ...    ...             ...        ...                ...
# 3328    AZ             192        415                 No
# 3329    WV              68        415                 No
# 3330    RI              28        510                 No
# 3331    CT             184        510                Yes
# 3332    TN              74        415                 No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# 2                         0              243.4            114.0
# ...

# %%
cleaned_df.to_csv('cleaned_df.csv') #To Export my Data
