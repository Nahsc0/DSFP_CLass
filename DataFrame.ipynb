# %%
import pandas as kudi

# %%
df = kudi.read_csv("telco_churn.csv") #read_csv() ------> This is known as a method

# %%
df.
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3323 non-null   float64
#  7   Total day calls         3323 non-null   float64
#  8   Total day charge        3315 non-null   float64
#  9   Total eve minutes       3324 non-null   float64
#  10  Total eve calls         3325 non-null   float64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3332 non-null   float64
# ...

# %%
for value in df['Churn']:
    print(value)
# Out:
# False
# False
# False
# False
# False
# False
# nan
# False
# False
# False
# True
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# True
# nan
# False
# False
# False
# False
# False
# False
# nan
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# ...

# %%
# Assuming 'data' is your DataFrame and 'Churn' is the column of interest
churn_count = df['Churn'].sum()

print('Number of True values in Churn column:', churn_count)
# Out:
# Number of True values in Churn column: 483

# %%
# # Assuming 'data' is your DataFrame
# # Set the maximum number of rows and columns to display to None
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# # Now print the DataFrame
# print(df)

# %%
print(df.iloc[:, [18, 19]])
# Out:
#       Customer service calls  Churn
# 0                        1.0  False
# 1                        1.0  False
# 2                        0.0  False
# 3                        2.0  False
# 4                        3.0  False
# 5                        0.0  False
# 6                        3.0    NaN
# 7                        0.0  False
# 8                        1.0  False
# 9                        0.0  False
# 10                       4.0   True
# 11                       0.0  False
# 12                       1.0  False
# 13                       3.0  False
# 14                       4.0  False
# 15                       4.0   True
# 16                       1.0  False
# 17                       3.0  False
# 18                       1.0  False
# 19                       1.0  False
# 20                       0.0  False
# 21                       5.0   True
# 22                       0.0    NaN
# 23                       2.0  False
# 24                       0.0  False
# ...

# %%
import matplotlib as plt
